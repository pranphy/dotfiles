# %%
# %run VscodeKeybindings.py
# Out:
# Complete map
# {"before":["ो"],"after":["J"]},{"before":["फ"],"after":["K"]},{"before":["['त', '्', 'र']"],"after":["q"]},

# %%
print(Maps.complete)
vk = {''.join(v):k for k,v in Maps.complete.items()}

print(vk)
# Out:
# {'0': '०', '1': '१', '2': '२', '3': '३', '4': '४', '5': '५', '6': '६', '7': '७', '8': '८', '9': '९', 'w': 'ध', 'e': 'भ', 'r': 'च', 't': 'त', 'y': 'थ', 'u': 'ग', 'i': 'ष', 'o': 'य', 'p': 'उ', 'a': 'ब', 's': 'क', 'd': 'म', 'f': 'ा', 'g': 'न', 'h': 'ज', 'j': 'व', 'k': 'प', 'l': 'ि', 'z': 'श', 'x': 'ह', 'c': 'अ', 'v': 'ख', 'b': 'द', 'n': 'ल', 'E': 'ऐ', 'U': 'ऊ', 'O': 'इ', 'P': 'ए', 'A': ['क', '्'], 'F': 'ँ', 'H': 'झ', 'J': 'ो', 'K': 'फ', 'L': 'ी', 'C': 'ऋ', 'V': 'ॐ', 'B': 'ौ', 'M': 'ः', '@': 'ई', '#': 'घ', '%': 'छ', '^': 'ट', '&': 'ठ', '*': 'ड', '(': 'ढ', ')': 'ण', '_': 'ओ', '+': 'ं', '.': '।', '/': 'र', '=': 'औ', '[': 'ृ', "'": 'ु', ']': 'े', '}': 'ै', '<': 'ङ', ';': 'स', 'q': ['त', '्', 'र'], 'Q': ['त', '्', 'त'], 'W': ['ध', '्'], 'R': ['च', '्'], 'T': ['त', '्'], 'Y': ['थ', '्'], 'I': ['क', '्', 'ष'], 'D': ['म', '्'], 'G': ['न', '्'], ':': ['स', '्'], 'Z': ['श', '्'], 'X': ['ह', '्'], 'N': ['ल', '्'], '>': ['श', '्', 'र'], '!': ['ज', '्', 'ञ'], '$': ['द', '्', 'ध']}
# ...

# %%
[[''.join(v),k] for k,v in dict(sorted(Maps.complete.items(),key = lambda x: len(x[1]),reverse=True)).items()]
# Out:
# [['त्र', 'q'],
#  ['त्त', 'Q'],
#  ['क्ष', 'I'],
#  ['श्र', '>'],
#  ['ज्ञ', '!'],
#  ['द्ध', '$'],
#  ['क्', 'A'],
#  ['ध्', 'W'],
#  ['च्', 'R'],
#  ['त्', 'T'],
#  ['थ्', 'Y'],
#  ['म्', 'D'],
#  ['न्', 'G'],
#  ['स्', ':'],
#  ['श्', 'Z'],
#  ['ह्', 'X'],
#  ['ल्', 'N'],
#  ['०', '0'],
#  ['१', '1'],
#  ['२', '2'],
#  ['३', '3'],
#  ['४', '4'],
#  ['५', '5'],
#  ['६', '6'],
#  ['७', '7'],
#  ['८', '8'],
#  ['९', '9'],
#  ['ध', 'w'],
#  ['भ', 'e'],
#  ['च', 'r'],
#  ['त', 't'],
#  ['थ', 'y'],
#  ['ग', 'u'],
#  ['ष', 'i'],
#  ['य', 'o'],
#  ['उ', 'p'],
#  ['ब', 'a'],
#  ['क', 's'],
#  ['म', 'd'],
#  ['ा', 'f'],
#  ['न', 'g'],
#  ['ज', 'h'],
#  ['व', 'j'],
#  ['प', 'k'],
#  ['ि', 'l'],
#  ['श', 'z'],
#  ['ह', 'x'],
#  ['अ', 'c'],
#  ['ख', 'v'],
#  ['द', 'b'],
#  ['ल', 'n'],
#  ['ऐ', 'E'],
#  ['ऊ', 'U'],
#  ['इ', 'O'],
#  ['ए', 'P'],
#  ['ँ', 'F'],
#  ['झ', 'H'],
#  ['ो', 'J'],
#  ['फ', 'K'],
#  ['ी', 'L'],
#  ['ऋ', 'C'],
#  ['ॐ', 'V'],
#  ['ौ', 'B'],
#  ['ः', 'M'],
#  ['ई', '@'],
# ...
